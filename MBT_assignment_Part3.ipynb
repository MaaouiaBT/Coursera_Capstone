# %% [markdown]
# #  Segmenting and Clustering Neighborhoods in Toronto

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ## Download and Explore Dataset

# %% [markdown]
# Use **BeautifulSoup** to scrape the  Wikipedia page

# %%
List_url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
source = requests.get(List_url).text

# %%
soup = BeautifulSoup(source, 'xml')
table=soup.find('table')
column_names=['Postalcode','Borough','Neighborhood']
df = pd.DataFrame(columns=column_names)

# %%
for tr_cell in table.find_all('tr'):
    row_data=[]
    for td_cell in tr_cell.find_all('td'):
        
        row_data.append(td_cell.text.strip())
       
    if len(row_data)==3:
        df.loc[len(df)] = row_data
        df.head()

# %%
 df.shape
# Out:
# (180, 3)

# %% [markdown]
# Ignore cells with a borough that is **Not assigned**

# %%
df=df[df['Borough']!='Not assigned']

# %%
df.shape
# Out:
# (103, 3)

# %%
df.head()
# Out:
#   Postalcode           Borough                                  Neighborhood
# 2        M3A        North York                                     Parkwoods
# 3        M4A        North York                              Victoria Village
# 4        M5A  Downtown Toronto                    Regent Park / Harbourfront
# 5        M6A        North York             Lawrence Manor / Lawrence Heights
# 6        M7A  Downtown Toronto  Queen's Park / Ontario Provincial Government

# %% [markdown]
# Check whether there is More than one neighborhood  exist in one postal code area.

# %%
df.Postalcode.nunique()
# Out:
# 103

# %%
df['Neighborhood']=df['Neighborhood'].str.replace('/',',')

# %%
df.head()
# Out:
#   Postalcode           Borough                                  Neighborhood
# 2        M3A        North York                                     Parkwoods
# 3        M4A        North York                              Victoria Village
# 4        M5A  Downtown Toronto                    Regent Park , Harbourfront
# 5        M6A        North York             Lawrence Manor , Lawrence Heights
# 6        M7A  Downtown Toronto  Queen's Park , Ontario Provincial Government

# %% [markdown]
# The number of rows of df dataframe:

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# # Part2

# %% [markdown]
# Add the geographical coordinates of the neighborhoods in the Toronto.

# %%
geo_df=pd.read_csv('http://cocl.us/Geospatial_data')

# %%
df.head()
# Out:
#   Postalcode           Borough                                  Neighborhood
# 2        M3A        North York                                     Parkwoods
# 3        M4A        North York                              Victoria Village
# 4        M5A  Downtown Toronto                    Regent Park , Harbourfront
# 5        M6A        North York             Lawrence Manor , Lawrence Heights
# 6        M7A  Downtown Toronto  Queen's Park , Ontario Provincial Government

# %%
geo_df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
geo_df.rename(columns={'Postal Code':'Postalcode'},inplace=True)
df_Geo_merged = pd.merge(df,geo_df , on='Postalcode')

# %%
df_Geo_merged.head(10)
# Out:
#   Postalcode           Borough                                  Neighborhood  \
# 0        M3A        North York                                     Parkwoods
# 1        M4A        North York                              Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park , Harbourfront
# 3        M6A        North York             Lawrence Manor , Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park , Ontario Provincial Government
# 5        M9A         Etobicoke                              Islington Avenue
# 6        M1B       Scarborough                               Malvern , Rouge
# 7        M3B        North York                                     Don Mills
# 8        M4B         East York              Parkview Hill , Woodbine Gardens
# 9        M5B  Downtown Toronto                      Garden District, Ryerson
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494
# 5  43.667856 -79.532242
# 6  43.806686 -79.194353
# 7  43.745906 -79.352188
# 8  43.706397 -79.309937
# 9  43.657162 -79.378937

# %%
df_Geo_merged.shape
# Out:
# (103, 5)

# %% [markdown]
# ## Explore and cluster the neighborhoods in Toronto

# %%
Toronto_df=df_Geo_merged[df_Geo_merged['Borough'].str.contains("Toronto")]
Toronto_df.head()
# Out:
#    Postalcode           Borough                                  Neighborhood  \
# 2         M5A  Downtown Toronto                    Regent Park , Harbourfront
# 4         M7A  Downtown Toronto  Queen's Park , Ontario Provincial Government
# 9         M5B  Downtown Toronto                      Garden District, Ryerson
# 15        M5C  Downtown Toronto                                St. James Town
# 19        M4E      East Toronto                                   The Beaches
#
#      Latitude  Longitude
# 2   43.654260 -79.360636
# 4   43.662301 -79.389494
# 9   43.657162 -79.378937
# 15  43.651494 -79.375418
# 19  43.676357 -79.293031

# %%
Toronto_df.shape
# Out:
# (39, 5)

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
CLIENT_ID = '4TFWLROI2BT5M3ZSNJGNFDIC3GFHYB0424Q14YFG10UHVG2V' # your Foursquare ID
CLIENT_SECRET = 'VYVFJ0RZPWR3FVOR4CTOJTOQ11XQS2UJ1O1AD2XEY5YQJKXX' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 4TFWLROI2BT5M3ZSNJGNFDIC3GFHYB0424Q14YFG10UHVG2V
# CLIENT_SECRET:VYVFJ0RZPWR3FVOR4CTOJTOQ11XQS2UJ1O1AD2XEY5YQJKXX

# %% [markdown]
# **Let's create a function to repeat the same process to all the neighborhoods in Toronto**

# %%
def getNearbyVenues(names, latitudes, longitudes):
    radius=500
    LIMIT=100
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# **Now write the code to run the above function on each neighborhood and create a new dataframe called toronto_venues**

# %%
toronto_venues = getNearbyVenues(names=Toronto_df['Neighborhood'],
                                   latitudes=Toronto_df['Latitude'],
                                   longitudes=Toronto_df['Longitude']
                                  )
# Out:
# Regent Park , Harbourfront
# Queen's Park , Ontario Provincial Government
# Garden District, Ryerson
# St. James Town
# The Beaches
# Berczy Park
# Central Bay Street
# Christie
# Richmond , Adelaide , King
# Dufferin , Dovercourt Village
# Harbourfront East , Union Station , Toronto Islands
# Little Portugal , Trinity
# The Danforth West , Riverdale
# Toronto Dominion Centre , Design Exchange
# Brockton , Parkdale Village , Exhibition Place
# India Bazaar , The Beaches West
# Commerce Court , Victoria Hotel
# Studio District
# Lawrence Park
# Roselawn
# Davisville North
# Forest Hill North & West
# High Park , The Junction South
# North Toronto West
# The Annex , North Midtown , Yorkville
# Parkdale , Roncesvalles
# Davisville
# University of Toronto , Harbord
# Runnymede , Swansea
# Moore Park , Summerhill East
# Kensington Market , Chinatown , Grange Park
# Summerhill West , Rathnelly , South Hill , Forest Hill SE , Deer Park
# CN Tower , King and Spadina , Railway Lands , Harbourfront West , Bathurst
#  Quay , South Niagara , Island airport
# Rosedale
# Stn A PO Boxes
# St. James Town , Cabbagetown
# First Canadian Place , Underground city
# Church and Wellesley
# Business reply mail Processing CentrE

# %%
toronto_venues.head()
# Out:
#                  Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Regent Park , Harbourfront               43.65426              -79.360636
# 1  Regent Park , Harbourfront               43.65426              -79.360636
# 2  Regent Park , Harbourfront               43.65426              -79.360636
# 3  Regent Park , Harbourfront               43.65426              -79.360636
# 4  Regent Park , Harbourfront               43.65426              -79.360636
#
#                     Venue  Venue Latitude  Venue Longitude  \
# 0        Roselle Desserts       43.653447       -79.362017
# 1           Tandem Coffee       43.653559       -79.361809
# 2  Cooper Koo Family YMCA       43.653249       -79.358008
# 3     Body Blitz Spa East       43.654735       -79.359874
# 4      Morning Glory Cafe       43.653947       -79.361149
#
#         Venue Category
# 0               Bakery
# 1          Coffee Shop
# 2  Distribution Center
# 3                  Spa
# 4       Breakfast Spot

# %% [markdown]
# **Let's check the size of the resulting dataframe**

# %%
toronto_venues.shape
# Out:
# (1627, 7)

# %%
toronto_venues.groupby('Neighborhood').count()
# Out:
#                                                     Neighborhood Latitude  \
# Neighborhood
# Berczy Park                                                            55
# Brockton , Parkdale Village , Exhibition Place                         22
# Business reply mail Processing CentrE                                  17
# CN Tower , King and Spadina , Railway Lands , H...                     18
# Central Bay Street                                                     64
# Christie                                                               18
# Church and Wellesley                                                   75
# Commerce Court , Victoria Hotel                                       100
# Davisville                                                             36
# Davisville North                                                        8
# Dufferin , Dovercourt Village                                          17
# First Canadian Place , Underground city                               100
# Forest Hill North & West                                                4
# Garden District, Ryerson                                              100
# Harbourfront East , Union Station , Toronto Isl...                    100
# High Park , The Junction South                                         24
# India Bazaar , The Beaches West                                        20
# Kensington Market , Chinatown , Grange Park                            62
# Lawrence Park                                                           4
# Little Portugal , Trinity                                              43
# Moore Park , Summerhill East                                            3
# North Toronto West                                                     20
# Parkdale , Roncesvalles                                                14
# Queen's Park , Ontario Provincial Government                           33
# Regent Park , Harbourfront                                             47
# Richmond , Adelaide , King                                             97
# Rosedale                                                                4
# Roselawn                                                                1
# Runnym
#
#         5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 2                     Theater        Breakfast Spot                  Café
# 4          Mexican Restaurant             Juice Bar    Italian Restaurant
# 9   Middle Eastern Restaurant   Japanese Restaurant       Bubble Tea Shop
# 15                 Restaurant   American Restaurant                 Hotel
# 19               Dessert Shop           Event Space  Ethiopian Restaurant
#
#    8th Most Common Venue        9th Most Common Venue 10th Most Common Venue
# 2     Mexican Restaurant               Farmers Market            Event Space
# 4             Hobby Shop          Fried Chicken Joint    Distribution Center
# 9     Italian Restaurant                   Restaurant              Bookstore
# 15   Japanese Restaurant                        Diner         Lingerie Store
# 19     Electronics Store  Eastern European Restaurant    Dumpling Restaurant

# %%
neighborhoods_venues_sorted.head()
# Out:
#    Cluster Labels                                       Neighborhood  \
# 0               0                                        Berczy Park
# 1               0     Brockton , Parkdale Village , Exhibition Place
# 2               0              Business reply mail Processing CentrE
# 3               0  CN Tower , King and Spadina , Railway Lands , ...
# 4               0                                 Central Bay Street
#
#   1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0           Coffee Shop    Seafood Restaurant                  Café
# 1                  Café           Coffee Shop        Breakfast Spot
# 2    Light Rail Station            Restaurant               Butcher
# 3       Airport Service        Airport Lounge      Airport Terminal
# 4           Coffee Shop    Italian Restaurant                  Café
#
#   4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 0              Beer Bar           Cheese Shop          Cocktail Bar
# 1                   Gym               Stadium         Burrito Place
# 2               Brewery  Fast Food Restaurant        Farmers Market
# 3               Airport                   Bar           Coffee Shop
# 4        Sandwich Place       Bubble Tea Shop          Burger Joint
#
#   7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 0    Italian Restaurant                Bakery        Farmers Market
# 1            Restaurant          Climbing Gym             Pet Store
# 2         Burrito Place         Auto Workshop                   Spa
# 3                 Plane   Rental Car Location      Sculpture Garden
# 4           Salad Place        Ice Cream Shop   Japanese Restaurant
#
#   10th Most Common Venue
# 0             Restaurant
# 1                 Bakery
# 2            Pizza Place
# 3          Boat or Ferry
# 4                    Spa

# %%
address = 'Toronto, CA'
geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto, CA are {}, {}.'.format(latitude, longitude)

# %% [markdown]
# The geograpical coordinate of Toronto, CA are 43.653963, -79.387207.

# %% [markdown]
# Given that the geolocator package is very unreliable, we have fixed (latitude,longitude) values in order we run again the code.

# %%
latitude = 43.653963
longitude = -79.387207

# %% [markdown]
# Finally, let's visualize the resulting clusters

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
with pd.ExcelWriter(r'REASUP.xlsx') as writer:
     neighborhoods_venues_sorted.to_excel(writer, sheet_name='Concat',index=False)
     toronto_grouped.to_excel(writer, sheet_name='Concat1',index=False)
     toronto_venues.to_excel(writer, sheet_name='Concat2',index=False)

# %%
toronto_grouped.shape
# Out:
# (39, 226)

# %% [markdown]
# ### Examine Clusters

# %% [markdown]
# **Cluster 1**

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#               Borough  Cluster Labels 1st Most Common Venue  \
# 2    Downtown Toronto               0           Coffee Shop
# 4    Downtown Toronto               0           Coffee Shop
# 9    Downtown Toronto               0           Coffee Shop
# 15   Downtown Toronto               0           Coffee Shop
# 20   Downtown Toronto               0           Coffee Shop
# 24   Downtown Toronto               0           Coffee Shop
# 25   Downtown Toronto               0         Grocery Store
# 30   Downtown Toronto               0           Coffee Shop
# 31       West Toronto               0                Bakery
# 36   Downtown Toronto               0           Coffee Shop
# 37       West Toronto               0                   Bar
# 41       East Toronto               0      Greek Restaurant
# 42   Downtown Toronto               0           Coffee Shop
# 43       West Toronto               0                  Café
# 47       East Toronto               0        Sandwich Place
# 48   Downtown Toronto               0           Coffee Shop
# 54       East Toronto               0                  Café
# 67    Central Toronto               0                   Gym
# 69       West Toronto               0       Thai Restaurant
# 73    Central Toronto               0        Clothing Store
# 74    Central Toronto               0                  Café
# 75       West Toronto               0             Gift Shop
# 79    Central Toronto               0           Pizza Place
# 80   Downtown Toronto               0                  Café
# 81       West Toronto               0           Coffee Shop
# 84   Downtown Toronto               0                  Café
# 86    Central Toronto               0                   Pub
# 87   Downtown Toronto               0       Airport Service
# 92   Downtown Toronto               0           Coffee Shop
# 96   Downtown Toronto               0           Coffee Shop
# 97   Downtown Toronto               0           Coffee Shop
# 99   Downtown Toronto               0           Coffee Shop
# 100      East Toronto               0    Light Rail Station
#
#     2nd Most Common Venue          3rd Most Common Venue  \
# 2                    Park                            Pub
# 4                   Diner                    Yoga Studio
# 9          Clothing Store                           Café
# 15                   Café                   Cocktail Bar
# 20     Seafood Restaurant                           Café
# 24     Italian Restaurant                           Café
# 25                   Café                           Park
# 30                   Café                            Gym
# 31               Pharmacy                    Music Venue
# 36               Aquarium                          Hotel
# 37             Restaurant  Vegetarian / Vegan Restaurant
# 41            Coffee Shop             Italian Restaurant
# 42                  Hotel                           Café
# 43            Coffee Shop                 Breakfast Spot
# 47   Fast Food Restaurant                            Gym
# 48             Restaurant                           Café
# 54            Coffee Shop                      Gastropub
# 67                  Hotel               Department Store
# 69     Mexican Restaurant                            Bar
# 73            Coffee Shop                    Yoga Studio
# 74         Sandwich Place                    Coffee Shop
# 75              Bookstore                  Movie Theater
# 79         Sandwich Place                   Dessert Shop
# 80             Restaurant                            Bar
# 81                   Café               Sushi Restaurant
# 84            Coffee Shop                            Bar
# 86            Coffee Shop                     Bagel Shop
# 87         Airport Lounge               Airport Terminal
# 92                   Café             Italian Restaurant
# 96                   Café             Italian Restaurant
# 97                   Café                     Restaurant
# 99    Japanese Restaurant                        Gay Bar
# 100            Restaurant                        Butcher
#
#            4th Most Common Venue          5th Most Common Venue  \
# 2                         Bakery                        Theater
# 4                           Park             Mexican Restaurant
# 9                 Cosmetics Shop      Middle Eastern Restaurant
# 15                      Beer Bar                     Restaurant
# 20                      Beer Bar                    Cheese Shop
# 24                Sandwich Place                Bubble Tea Shop
# 25                    Baby Store                    Gas Station
# 30                    Restaurant                  Deli / Bodega
# 31                     Wine Shop                    Supermarket
# 36                          Café                     Restaurant
# 37                          Café               Asian Restaurant
# 41                    Restaurant         Furniture / Home Store
# 42                    Restaurant                    Salad Place
# 43                           Gym                        Stadium
# 47                   Coffee Shop                        Brewery
# 48                         Hotel                            Gym
# 54                       Brewery                         Bakery
# 67                Sandwich Place                 Breakfast Spot
# 69                          Café                          Diner
# 73          Fast Food Restaurant            Rental Car Location
# 74                    Donut Shop                            Pub
# 75   Eastern European Restaurant             Italian Restaurant
# 79                   Coffee Shop               Sushi Restaurant
# 80            Italian Restaurant            Japanese Restaurant
# 81                           Pub                    Pizza Place
# 84         Vietnamese Restaurant  Vegetarian / Vegan Restaurant
# 86                   Supermarket                           Bank
# 87                       Airport                            Bar
# 92                    Restaurant                          Hotel
# 96                        Bakery                         Market
# 97                         Hotel                            Gym
# 99              Sushi Restaurant                     Restaurant
# 100                      Brewery           Fast Food Restaurant
#
#     6th Most Common Venue 7th Most Common Venue    8th Most Common Venue  \
# 2          Breakfast Spot                  Café       Mexican Restaurant
# 4               Juice Bar    Italian Restaurant               Hobby Shop
# 9     Japanese Restaurant       Bubble Tea Shop       Italian Restaurant
# 15    American Restaurant                 Hotel      Japanese Restaurant
# 20           Cocktail Bar    Italian Restaurant                   Bakery
# 24           Burger Joint           Salad Place           Ice Cream Shop
# 25            Candy Store    Italian Restaurant       Athletics & Sports
# 30                  Hotel       Thai Restaurant         Sushi Restaurant
# 31          Grocery Store                   Bar     Gym / Fitness Center
# 36     Italian Restaurant               Brewery      Sporting Goods Shop
# 37            Men's Store           Coffee Shop       Italian Restaurant
# 41              Bookstore        Ice Cream Shop                      Spa
# 42    Japanese Restaurant    Italian Restaurant      American Restaurant
# 43          Burrito Place            Restaurant             Climbing Gym
# 47          Burrito Place            Restaurant                      Pub
# 48    American Restaurant    Italian Restaurant      Japanese Restaurant
# 54    American Restaurant           Yoga Studio  Comfort Food Restaurant
# 67      Food & Drink Shop                  Park     Gym / Fitness Center
# 69     Italian Restaurant           Flea Market      Fried Chicken Joint
# 73           Dessert Shop                 Diner       Salon / Barbershop
# 74              BBQ Joint        History Museum        Indian Restaurant
# 75                Dog Run                   Bar                     Bank
# 79                   Café                   Gym       Italian Restaurant
# 80              Bookstore                Bakery           Sandwich Place
# 81     Italian Restaurant             Juice Bar            Burrito Place
# 84     Mexican Restaurant          Dessert Shop       Chinese Restaurant
# 86    Fried Chicken Joint            Restaurant               Sports Bar
# 87            Coffee Shop                 Plane      Rental Car Location
# 92     Seafood Restaurant              Beer Bar      Japanese Restaurant
# 96            Pizza Place                  Park                      Pub
# 97    Japanese Restaurant             Gastropub       Seafood Restaurant
# 99            Yoga Studio           Pizza Place                Gastropub
# 100        Farmers Market         Burrito Place            Auto Workshop
#
#     9th Most Common Venue    10th Most Common Venue
# 2          Farmers Market               Event Space
# 4     Fried Chicken Joint       Distribution Center
# 9              Restaurant                 Bookstore
# 15                  Diner            Lingerie Store
# 20         Farmers Market                Restaurant
# 24    Japanese Restaurant                       Spa
# 25             Restaurant               Coffee Shop
# 30           Concert Hall            Clothing Store
# 31                   Park                      Bank
# 36    Fried Chicken Joint            Scenic Lookout
# 37      French Restaurant                    Bistro
# 41              Juice Bar                   Brewery
# 42     Seafood Restaurant                 Gastropub
# 43              Pet Store                    Bakery
# 47              Pet Store             Movie Theater
# 48     Seafood Restaurant                 Gastropub
# 54     Seafood Restaurant            Sandwich Place
# 67                Gay Bar                 Gift Shop
# 69              Speakeasy    Furniture / Home Store
# 73     Mexican Restaurant        Chinese Restaurant
# 74               Pharmacy               Pizza Place
# 75           Dessert Shop                Restaurant
# 79         Farmers Market                  Pharmacy
# 80                   Bank                  Beer Bar
# 81             Restaurant              Dessert Shop
# 84         Farmers Market             Grocery Store
# 86            Pizza Place       American Restaurant
# 87       Sculpture Garden             Boat or Ferry
# 92                    Gym            Farmers Market
# 96             Restaurant       Japanese Restaurant
# 97                    Bar       American Restaurant
# 99                  Hotel  Mediterranean Restaurant
# 100                   Spa               Pizza Place

# %% [markdown]
# **Cluster 2**

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels 1st Most Common Venue  \
# 62  Central Toronto               1                Garden
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 62           Yoga Studio          Dessert Shop           Event Space
#
#    5th Most Common Venue 6th Most Common Venue        7th Most Common Venue  \
# 62  Ethiopian Restaurant     Electronics Store  Eastern European Restaurant
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 62   Dumpling Restaurant            Donut Shop       Doner Restaurant

# %% [markdown]
# **Cluster 3**

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 83   Central Toronto               2                  Park
# 91  Downtown Toronto               2                  Park
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 83            Playground          Tennis Court      Department Store
# 91            Playground                 Trail      Department Store
#
#    5th Most Common Venue 6th Most Common Venue        7th Most Common Venue  \
# 83  Ethiopian Restaurant     Electronics Store  Eastern European Restaurant
# 91  Ethiopian Restaurant     Electronics Store  Eastern European Restaurant
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 83   Dumpling Restaurant            Donut Shop       Doner Restaurant
# 91   Dumpling Restaurant            Donut Shop       Doner Restaurant

# %% [markdown]
# **Cluster 4**

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels 1st Most Common Venue  \
# 61  Central Toronto               3                Lawyer
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 61           Swim School              Bus Line                  Park
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 61     German Restaurant          Dessert Shop  Ethiopian Restaurant
#
#    8th Most Common Venue        9th Most Common Venue 10th Most Common Venue
# 61     Electronics Store  Eastern European Restaurant    Dumpling Restaurant

# %% [markdown]
# **Cluster 5**

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels 1st Most Common Venue  \
# 19     East Toronto               4     Health Food Store
# 68  Central Toronto               4                  Park
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 19                 Trail                   Pub           Yoga Studio
# 68         Jewelry Store                 Trail      Sushi Restaurant
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 19          Dessert Shop           Event Space  Ethiopian Restaurant
# 68          Dessert Shop  Ethiopian Restaurant     Electronics Store
#
#           8th Most Common Venue        9th Most Common Venue  \
# 19            Electronics Store  Eastern European Restaurant
# 68  Eastern European Restaurant          Dumpling Restaurant
#
#    10th Most Common Venue
# 19    Dumpling Restaurant
# 68             Donut Shop
